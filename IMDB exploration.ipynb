# %% [markdown]
# <H1> Importing and Exploring Provided Datasets </H1>

# %% [markdown]
# <H4> Import the necessary packages.</H4>

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns

# %% [markdown]
# *Bring in the file names for easy access.*

# %%
zippedData = ['bom.movie_gross.csv.gz','imdb.name.basics.csv.gz','imdb.title.akas.csv.gz',
              'imdb.title.basics.csv.gz','imdb.title.crew.csv.gz',
              'imdb.title.principals.csv.gz','imdb.title.ratings.csv.gz',
              'rt.movie_info.tsv.gz','rt.reviews.tsv.gz','tmdb.movies.csv.gz',
              'tn.movie_budgets.csv.gz']

# %%
bom_movie_gross = pd.read_csv("zippedData/{}".format(zippedData[0]))
imdb_name = pd.read_csv("zippedData/{}".format(zippedData[1]))
imdb_title_aka = pd.read_csv("zippedData/{}".format(zippedData[2]))
imdb_title_basics = pd.read_csv("zippedData/{}".format(zippedData[3]))
imdb_title_crew = pd.read_csv("zippedData/{}".format(zippedData[4]))
imdb_title_principals = pd.read_csv("zippedData/{}".format(zippedData[5]))
imdb_title_rating = pd.read_csv("zippedData/{}".format(zippedData[6]))
rt_movie_info = pd.read_csv("zippedData/{}".format(zippedData[7]),sep='\t')
#df8 = pd.read_csv("zippedData/{}".format(zippedData[8]),sep='\t') buggy, haven't dug in
tmdb_movies = pd.read_csv("zippedData/{}".format(zippedData[9]))
tn_movie_budget = pd.read_csv("zippedData/{}".format(zippedData[10]))

# %%
bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
imdb_name.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
imdb_title_aka.head()
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
imdb_title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_title_crew.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
imdb_title_principals
# Out:
#             tconst  ordering      nconst  category       job  \
# 0        tt0111414         1   nm0246005     actor       NaN
# 1        tt0111414         2   nm0398271  director       NaN
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor       NaN
# 4        tt0323808         1   nm3579312   actress       NaN
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor       NaN
# 1028182  tt9692684         2   nm4929530      self       NaN
# 1028183  tt9692684         3  nm10441594  director       NaN
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters
# 0                 ["The Man"]
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4            ["Beth Boothby"]
# ...                       ...
# 1028181  ["Ebenezer Scrooge"]
# 1028182   ["Herself","Regan"]
# 1028183                   NaN
# 1028184                   NaN
# 1028185                   NaN
#
# [1028186 rows x 6 columns]

# %%
imdb_title_rating
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
imdb=imdb_title_rating.merge(imdb_title_principals,on='tconst')
imdb=imdb.merge(imdb_title_basics,on='tconst')
imdb=imdb.merge(imdb_name,on='nconst')
imdb=imdb.merge(imdb_title_crew,on='tconst')
imdb=imdb[['original_title','genres','start_year','averagerating','category','primary_profession','primary_name']].where(imdb['start_year']>2000)
imdb=imdb.drop_duplicates('original_title')
imdb.dropna(inplace=True)
imdb['original_title'].unique()
imdb['start_year'].unique()
imdb['averagerating'].unique()
imdb_final=imdb[['genres','averagerating']]
imdb_final
# Out:
#                       genres  averagerating
# 0                    Romance            8.3
# 10      Comedy,Drama,Romance            8.3
# 20                    Comedy            6.4
# 30            Comedy,Romance            6.4
# 40                    Comedy            6.9
# ...                      ...            ...
# 629569           Documentary            6.0
# 629575           Documentary            8.5
# 629578           Documentary            7.3
# 629580                Comedy            9.0
# 629594           Documentary            4.3
#
# [68747 rows x 2 columns]

# %%
imdb
# Out:
#                              original_title                genres  start_year  \
# 0                          Laiye Je Yaarian               Romance        2019
# 10                          Bhajjo Veero Ve  Comedy,Drama,Romance        2018
# 20                                Thug Life                Comedy        2017
# 30                    Daddy Cool Munde Fool        Comedy,Romance        2013
# 40                    Ronde Sare Vyah Picho                Comedy        2013
# ...                                     ...                   ...         ...
# 629569       Mykonos, the Soul of an Island           Documentary        2018
# 629575                              Kananga           Documentary        2018
# 629578                               Heroes           Documentary        2019
# 629580                       Postarica Ruza                Comedy        2016
# 629594  Mad House: A Paranormal Documentary           Documentary        2019
#
#         averagerating             category  \
# 0                 8.3  production_designer
# 10                8.3  production_designer
# 20                6.4                actor
# 30                6.4                actor
# 40                6.9                actor
# ...               ...                  ...
# 629569            6.0                actor
# 629575            8.5             director
# 629578            7.3             director
# 629580            9.0                actor
# 629594            4.3                 self
#
#                         primary_profession        primary_name
# 0       production_designer,art_department      Kazi Rafik Ali
# 10      production_designer,art_department      Kazi Rafik Ali
# 20                                   actor        Harish Verma
# 30                                   actor        Harish Verma
# 40                                   actor        Harish Verma
# ...                                    ...                 ...
# 629569                            composer     Aris Gerontakis
# 629575     director,writer,cinematographer   Pavlos Tripodakis
# 629578            director,producer,editor         Köken Ergun
# 629580                      actor,director  Vjekoslav Jankovic
# 629594                            producer     Alex Bobulinski
#
# [68747 rows x 7 columns]

# %%
imdb_final[["One","Two","Three"]]=imdb_final.genres.str.split(pat=',', n=- 1, expand=True)
imdb_final
imdb_final_one=imdb_final[['One','averagerating']]
#imdb_final_one.groupby('One').mean().plot.bar()
imdb_final
imdb_final_two=imdb_final[['Two','averagerating']]    
imdb_final_three=imdb_final[['Three','averagerating']]
imdb_final_one=imdb_final_one.rename(columns={"One":"Genre"})
imdb_final_two=imdb_final_two.rename(columns={"Two":"Genre"})
imdb_final_three=imdb_final_three.rename(columns={"Three":"Genre"})
t=pd.concat([imdb_final_three,imdb_final_two,imdb_final_one])
t.groupby('Genre').mean().plot.bar()
# Out:
# C:\Users\weinb\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# <AxesSubplot:xlabel='Genre'>

# %%
imdb_job=imdb[['primary_profession','primary_name','averagerating']]
imdb_job[['Director','Director2','Director3']]=imdb_job.primary_profession.str.split(pat=',', n=- 1, expand=True)
imdb_job_director=imdb_job[imdb_job['primary_profession'].str.contains('director')]
imdb_job_director_name=imdb_job_director[['averagerating','primary_name']]
imdb_job_director_name=imdb_job_director_name.groupby(['primary_name']).mean().sort_values('averagerating',ascending=False)
imdb_job_director_name.head(10)
# Out:
# C:\Users\weinb\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                    averagerating
# primary_name
# Lindsay Thompson            10.0
# Ivana Diniz                 10.0
# Matt Hopkins                10.0
# Masahiro Hayakawa           10.0
# Soudabeh Moradian           10.0
# Amoghavarsha                 9.9
# Maria Bagnat                 9.8
# Edward Payson                9.8
# David Sipos                  9.8
# Will Watson                  9.7

# %%
rt_movie_info

# %%
#df8.head()

# %%
tmdb_movies

# %%
tn_movie_budget
